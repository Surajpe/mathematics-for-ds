# %% [markdown]
# Code is not mandatory. You can solve these problems on your own.

# %% [markdown]
# # Problem 1
#
# In a group of 25 people, 18 have a mortgage, 13 own some shares and 2 people have neither a mortgage nor any shares. How many people have both?

# %%
nU=25                                   #Total peoples

# %%
nM=18                                   # number of mortgagers

# %%
nS=13                                   # number of shares owners

# %%
nMNS=2                                  # neigther shares owners nor mortgage

# %%
nMUS=nU-nMNS                            # number of people who definately have shares or mortgage

# %%
nMIS=nM+nS-nMUS                         # Peoples who has both shares and mortgage

# %%
nMIS
# Out:
# 8

# %% [markdown]
# # Problem 2
#
# A contestant on a game show is asked two questions. The probability that she gets the first question correct is 0.3 and the probability that she gets the second question correct is 0.4. Given that the probability that she gets both questions correct is 0.1, calculate the probability that:
# 1. She gets either the first, the second or both questions right
# 2. She gets both questions wrong

# %%
P_F=0.3      # probability of getting first question right

# %%
P_S=0.4      # probability of getting second question right

# %%
P_FIS=0.1    #  probability that she gets both questions correct is 0.1

# %%
P_FUS=P_F+P_S-P_FIS     # probability of getting both question right
print(P_FUS)
# Out:
# 0.6

# %%
P_NFUS=1-P_FUS          # both question wrong
print(P_NFUS)
# Out:
# 0.4

# %% [markdown]
# # Problem 3
#
# A 4 digit PIN is selected. What is the probability that there are no repeated digits?

# %%
def fact(n):
  f=1
  for i in range(n):
    f=f*(i+1)
  return f

# %%
def P(n,r):
  return fact(n)/fact(r)

# %%
P(10,4)
# Out:
# 151200.0

# %%
from itertools import permutations

# %%
seq= permutations([0,1,2,3,4,5,6,8,9],4)

for p in list(seq):
  print(p)
# Out:
# (0, 1, 2, 3)
# (0, 1, 2, 4)
# (0, 1, 2, 5)
# (0, 1, 2, 6)
# (0, 1, 2, 8)
# (0, 1, 2, 9)
# (0, 1, 3, 2)
# (0, 1, 3, 4)
# (0, 1, 3, 5)
# (0, 1, 3, 6)
# (0, 1, 3, 8)
# (0, 1, 3, 9)
# (0, 1, 4, 2)
# (0, 1, 4, 3)
# (0, 1, 4, 5)
# (0, 1, 4, 6)
# (0, 1, 4, 8)
# (0, 1, 4, 9)
# (0, 1, 5, 2)
# (0, 1, 5, 3)
# (0, 1, 5, 4)
# (0, 1, 5, 6)
# (0, 1, 5, 8)
# (0, 1, 5, 9)
# (0, 1, 6, 2)
# (0, 1, 6, 3)
# (0, 1, 6, 4)
# (0, 1, 6, 5)
# (0, 1, 6, 8)
# (0, 1, 6, 9)
# (0, 1, 8, 2)
# (0, 1, 8, 3)
# (0, 1, 8, 4)
# (0, 1, 8, 5)
# (0, 1, 8, 6)
# (0, 1, 8, 9)
# (0, 1, 9, 2)
# (0, 1, 9, 3)
# (0, 1, 9, 4)
# (0, 1, 9, 5)
# (0, 1, 9, 6)
# (0, 1, 9, 8)
# (0, 2, 1, 3)
# (0, 2, 1, 4)
# (0, 2, 1, 5)
# (0, 2, 1, 6)
# (0, 2, 1, 8)
# (0, 2, 1, 9)
# (0, 2, 3, 1)
# (0, 2, 3, 4)
# (0, 2, 3, 5)
# (0, 2, 3, 6)
# (0, 2, 3, 8)
# (0, 2, 3, 9)
# (0, 2, 4, 1)
# (0, 2, 4, 3)
# (0, 2, 4, 5)
# (0, 2, 4, 6)
# (0, 2, 4, 8)
# (0, 2, 4, 9)
# (0, 2, 5, 1)
# (0, 2, 5, 3)
# (0, 2, 5, 4)
# (0, 2, 5, 6)
# (0, 2, 5, 8)
# (0, 2, 5, 9)
# ...

# %% [markdown]
# # Problem 4
# In a certain state’s lottery, 48 balls numbered 1 through 48 are placed in a machine and six of them are drawn at random. If the six numbers drawn match the numbers that a player had chosen, the player wins $1,000,000. In this lottery, the order the numbers are drawn in doesn’t matter. Compute the probability that you win the million-dollar prize if you purchase a single lottery ticket.

# %%
def fact(n):
  f=1
  for i in range(n):
    f=f*(i+1)
  return f

# %%
def C(n,r):
  return fact(n)/fact(n-r)*fact(r)

# %%
C(48,6)                     # number of combination outcomes when we choose randomly 6 balls out of 48 balls
# Out:
# 6361551820800.0

# %% [markdown]
# The number of winning combinations are 6361551820800.0.

# %% [markdown]
# # Problem 5
#
# A person has three routes to get to work. The probability that he arrives on time using
# routes A, B and C are 60% , 62% and 70% respectively. If he is equally likely to
# choose any of the routes, and arrives at work on time, what is the probability that he
# chose route B?

# %%
P_A = 0.34          # choosing route A because the person equally llikely to choose any of the routes

# %%
P_B = 0.34          # choosing route B because the person equally llikely to choose any of the routes

# %%
P_C = 0.34          # choosing route C because the person equally llikely to choose any of the routes

# %%
P_OA = 0.6            # Probability of reaching on time if the person uses reoute A

# %%
P_OB = 0.62           # Probability of reaching on time if the person  uses reoute B

# %%
P_OC = 0.7           # Probability of reaching on time if the person  uses reoute C

# %%
# P_BO= (P_OB * P_B)/P(O)          # the probability that the person choose route B given that he/she arrives on time

# %%
P_O = P_OA*P_A+P_OB*P_A+P_OC*P_A

# %%
P_BO= (P_OB * P_B)/P_O

# %%
P_BO
# Out:
# 0.3229166666666667
